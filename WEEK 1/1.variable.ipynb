# %%
age = 25

# %%
score = 3.5

# %%
print("Age = ", age)
print("score = ", score)
# Out:
# Age =  25
# score =  3.5

# %%
type(score)
# Out:
# float

# %%
type(age)
# Out:
# int

# %%
print(score+1)
# Out:
# 4.5

# %%
name ="Waqar Musa"

print (name + " is a good boy ")
# Out:
# Waqar Musa is a good boy

# %%
isPassed = True

print(isPassed )
# Out:
# True
