# %%
#############     TUPLE  ################

#orderd but it cannot be changed

# %%
colour = ("red", "black","orange")
print(colour)
# Out:
# ('red', 'black', 'orange')

# %%
print(colour[1])
# Out:
# black

# %%
##cannot be changed lets try changing it 

colour[0] = "blue"  # This will raise an error because tuples are immutable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 ##cannot be changed lets try changing it
# ----> 3 colour[0] = "blue"  # This will raise an error because tuples are immutable
#
# TypeError: 'tuple' object does not support item assignment

# %%
######################## METHODS  ##########################


number = (2,3,4,2,3,6,3)

print(number.count(3))  # This will return the count of the number 3 in the tuple  



print(number.index(2)) #
# Out:
# 3
# 0
