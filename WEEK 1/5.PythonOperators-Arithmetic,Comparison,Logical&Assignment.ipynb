# %%
print(5 + 3)
print(10 - 4)

# addition
# subtraction
# Out:
# 8
# 6

# %%
print(2 * 6)   # multiply
print(15 / 3)   # divide
print(17 // 3) # floor divide
# Out:
# 12
# 5.0
# 5

# %%
print(10 % 3)      # remainder
print(2 ** 3)      #exponent

print(5 == 5)       # equality
print(7 != 3)       # Inequality
print(10 > 2)
print(4< 1)
# Out:
# 1
# 8
# True
# True
# True
# False
