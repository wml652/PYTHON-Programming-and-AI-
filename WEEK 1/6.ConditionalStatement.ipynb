# %%
temp = int(input("Please write your temp: "))

# %%
if temp > 30:
    print("It's a hot day")

else :
    print ("not hot")
# Out:
# not hot

# %%
score = 85


# elif

if score >= 90:
 print("A+")

elif score >= 80:
 print("A")

else:
 print("Try again!")
# Out:
# A

# %%
age = 17
country = "Pakistan"

if age >= 18:
    if country == "Pakistan":
        print("You can vote in Pakistan.")

# %%
if age > 18 and country == "Pakistan":
 print("Eligible voter")
else:
 print("Not eligible voter")

# nested if

# combine conditions
