# %%
def greet():
    print("Hello World!!")

greet()
# Out:
# Hello World!!

# %%
def greet(name):
    name = input("Enter Your Name:")
    print("hello ", name ," !!")



def greet2(name):
    print("hello ", name ," !!")


name = "ALI"
greet(name)
greet2(name)
# Out:
# hello  waqar  !!
# hello  ALI  !!
