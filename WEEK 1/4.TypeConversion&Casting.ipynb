# %%
age = "34"

print(age)
# Out:
# 34

# %%
type(age)
# Out:
# str

# %%
print(int(age)+1)
# Out:
# 35

# %%
input("Please write your age")
# Out:
# ''

# %%
age = input("Please write your age")


type(age)
# Out:
# str

# %%
print(age)
# Out:
# 31

# %%
myAge = int(age)

type(myAge)
# Out:
# int

# %%
print(myAge)
# Out:
# 31
