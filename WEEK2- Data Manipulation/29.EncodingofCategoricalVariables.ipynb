# %%
import pandas as pd
# %pip install scikit-learn


print("Library installed successfully")
# Sample data
df = pd.DataFrame({
"City": ["Lahore", "Karachi", "Islamabad", "Lahore", "Karachi"],
"Segment": ["A", "B", "A", "c", "B"],
"Sales": [200, 240, 180, 300, 220]
})

print(df)
# Out:
# ...
#   Using cached scipy-1.18.1-cp314-cp314-win_amd64.whl.metadata (61 kB)
# ...
#    ---------------------------------------- 0.0/8.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.4 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.4 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/8.4 MB 1.9 MB/s eta 0:00:05
#    --- ------------------------------------ 0.8/8.4 MB 1.9 MB/s eta 0:00:05
#    --- ------------------------------------ 0.8/8.4 MB 1.9 MB/s eta 0:00:05
#    ------- -------------------------------- 1.6/8.4 MB 1.6 MB/s eta 0:00:05
#    ---------- ----------------------------- 2.1/8.4 MB 1.7 MB/s eta 0:00:04
#    ---------- ----------------------------- 2.1/8.4 MB 1.7 MB/s eta 0:00:04
#    ---------- ----------------------------- 2.1/8.4 MB 1.7 MB/s eta 0:00:04
#    ----------- ---------------------------- 2.4/8.4 MB 1.2 MB/s eta 0:00:05
# ...

# %%
# One-hot encode
encoded = pd.get_dummies(df, columns=["City", "Segment"], drop_first=True)
print(encoded)
# Out:
#    Sales  City_Karachi  City_Lahore  Segment_B  Segment_c
# 0    200         False         True      False      False
# 1    240          True        False       True      False
# 2    180         False        False      False      False
# 3    300         False         True      False       True
# 4    220          True        False       True      False

# %%
from sklearn.preprocessing import OrdinalEncoder

df2 = pd.DataFrame({
"Size": ["Small", "Medium", "Large", "Medium", "Large"]

})
print(df2)
# Out:
#      Size
# 0   Small
# 1  Medium
# 2   Large
# 3  Medium
# 4   Large

# %%
encoder = OrdinalEncoder(categories=[["Small", "Medium", "Large"]])
df2["Size_encoded"] = encoder.fit_transform(df2[["Size"]])
print(df2)
# Out:
#      Size  Size_encoded
# 0   Small           0.0
# 1  Medium           1.0
# 2   Large           2.0
# 3  Medium           1.0
# 4   Large           2.0

# %%
# One-Hot Encoding with Pandas

import pandas as pd

df = pd.read_csv("loan_default_feature_engineering.csv")

df.head(5)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[13], line 5
#       1 # One-Hot Encoding with Pandas
#       2
#       3 import pandas as pd
#       4
# ----> 5 df = pd.read_csv("loan_default_feature_engineering.csv")
#       6
#       7 df.head(5)
#
# ...
