# %%
# !pip install pandas

# %%
import pandas as pd

# %%
s = pd.Series([20, 20, 30, 40, 50],['a','b','c','d','e'])
print(s)
# Out:
# a    20
# b    20
# c    30
# d    40
# e    50
# dtype: int64

# %%
# Index vs Values
print("Values:", s.values)
print("Index:", s.index)
print("Dtype:", s.dtype)
# Out:
# Values: [20 20 30 40 50]
# Index: Index(['a', 'b', 'c', 'd', 'e'], dtype='object')
# Dtype: int64

# %%
print(s.head)
# Out:
# <bound method NDFrame.head of a    20
# b    20
# c    30
# d    40
# e    50
# dtype: int64>

# %%
print(s.tail)
# Out:
# <bound method NDFrame.tail of a    20
# b    20
# c    30
# d    40
# e    50
# dtype: int64>

# %%
print(s.value_counts())
# Out:
# 20    2
# 30    1
# 40    1
# 50    1
# Name: count, dtype: int64
