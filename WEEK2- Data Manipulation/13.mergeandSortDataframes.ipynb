# %%
import pandas as pd

# %%
# Sample DataFrames
customers = pd.DataFrame({
'CustomerID': [1,2,3],
'Name': ['Alice', 'Bob', 'Charlie']

})

orders = pd.DataFrame({
'OrderID': [101,102,103,104],
'CustomerID': [1,2,2,3],
'Amount7': [250, 150, 200, 300]
})

# %%
# Inner merge on CustomerID
df_inner = pd.merge(customers, orders, on='CustomerID', how='inner')
print("Inner Merge: \n", df_inner)
# Out:
# Inner Merge:
#     CustomerID     Name  OrderID  Amount7
# 0           1    Alice      101      250
# 1           2      Bob      102      150
# 2           2      Bob      103      200
# 3           3  Charlie      104      300

# %%
# Left merge
df_left = pd.merge(customers, orders, on='CustomerID', how='left')
print("\nLeft Merge: \n", df_left)
# Out:
# Left Merge:
#     CustomerID     Name  OrderID  Amount7
# 0           1    Alice      101      250
# 1           2      Bob      102      150
# 2           2      Bob      103      200
# 3           3  Charlie      104      300

# %%
# Concatenate rows example
df_concat = pd.concat([customers, customers])
print("\nConcatenated Rows:\n", df_concat)
# Out:
# Concatenated Rows:
#     CustomerID     Name
# 0           1    Alice
# 1           2      Bob
# 2           3  Charlie
# 0           1    Alice
# 1           2      Bob
# 2           3  Charlie
